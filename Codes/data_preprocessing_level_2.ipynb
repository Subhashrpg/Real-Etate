# %%
# importing
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# reading data
df = pd.read_csv("datasets\Gurgaon\Flats\properties.csv")
df.sample(5)
# Out:
#                                  property_name property_type  \
# 2392           4 BHK Flat in Sector 85 Gurgaon          flat
# 761   2 Bedroom House for sale in Baldev Nagar         house
# 1365           3 BHK Flat in Sector 90 Gurgaon          flat
# 1355     4 Bedroom House for sale in Vir Nagar         house
# 2336           3 BHK Flat in Sector 81 Gurgaon          flat
#
#                         society  price  price_per_sqft    area  \
# 2392  orris carnation residency   0.90          4531.0  1986.0
# 761                 independent   0.53          5888.0   900.0
# 1365          dlf regal gardens   1.20          6837.0  1755.0
# 1355                independent   0.78          9725.0   802.0
# 2336             dlf the ultima   2.12         10080.0  2103.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 2392  Super Built up area 1975(183.48 sq.m.)Built Up...        4         4
# ...

# %%
df.shape
# Out:
# (3961, 20)

# %%
# checking duplicates values
df.duplicated().sum()
# Out:
# 0

# %%
# data summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3961 entries, 0 to 3960
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3961 non-null   object
#  1   property_type    3961 non-null   object
#  2   society          3960 non-null   object
#  3   price            3941 non-null   float64
#  4   price_per_sqft   3941 non-null   float64
#  5   area             3941 non-null   float64
#  6   areaWithType     3961 non-null   object
#  7   bedRoom          3961 non-null   int64
#  8   bathroom         3961 non-null   int64
#  9   balcony          3961 non-null   object
#  10  additionalRoom   3961 non-null   object
#  11  address          3950 non-null   object
#  12  floor_num        3940 non-null   float64
#  13  facing           2784 non-null   object
#  14  agePossession    3960 non-null   object
#  15  nearbyLocations  3754 non-null   object
# ...

# %%
# checking null values
df.isnull().sum()
# Out:
# property_name         0
# property_type         0
# society               1
# price                20
# price_per_sqft       20
# area                 20
# areaWithType          0
# bedRoom               0
# bathroom              0
# balcony               0
# additionalRoom        0
# address              11
# floor_num            21
# facing             1177
# agePossession         1
# nearbyLocations     207
# description           0
# furnishDetails     1032
# features            709
# rating              450
# dtype: int64

# %%
df.insert(loc=3,column="sector",value=df.property_name.str.split("in").str.get(1).str.strip().str.replace("Gurgaon","").str.strip().str.lower())

# %%
df.head()
# Out:
#                                     property_name property_type  \
# 0        12 Bedroom House for sale in Malibu Town         house
# 1  5 Bedroom House for sale in Sector 109 Gurgaon         house
# 2                2 BHK Flat in Sector 102 Gurgaon          flat
# 3                2 BHK Flat in Sector 99A Gurgaon          flat
# 4                             2 BHK Flat in Sohna          flat
#
#                                 society       sector  price  price_per_sqft  \
# 0                          malibu towne  malibu town   8.50         53125.0
# 1   international city by sobha phase 1   sector 109  12.00         20000.0
# 2  shapoorji pallonji joyville gurugram   sector 102   1.28         10534.0
# 3                     conscient habitat   sector 99a   0.27          5599.0
# 4                     gls arawali homes        sohna   0.32          6722.0
#
#      area                                       areaWithType  bedRoom  \
# ...

# %%
df.sector.value_counts()
# Out:
# sohna                                                        163
# sector 102                                                   113
# sector 85                                                    110
# sector 92                                                    104
# sector 69                                                     94
# sector 81                                                     90
# sector 65                                                     90
# sector 90                                                     90
# sector 109                                                    88
# sector 79                                                     80
# sector 83                                                     69
# sector 37d                                                    68
# sector 86                                                     67
# sector 104                                                    66
# ...

# %%
replacement = {
    'dharam colony':'sector 12','krishna colony':'sector 7','suncity':'sector 54','prem nagar':'sector 13','mg road':'sector 28',
    'gandhi nagar':'sector 28', 'laxmi garden':'sector 11', 'shakti nagar':'sector 11', 'baldev nagar':'sector 7',
    'shivpuri':'sector 7', 'garhi harsaru':'sector 17', 'imt manesar':'manesar', 'adarsh nagar':'sector 12','bhim nagar':'sector 6',
    'shivaji nagar':'sector 11', 'madanpuri':'sector 7', 'saraswati vihar':'sector 28', 'arjun nagar':'sector 8',
    'ravi nagar':'sector 9', 'vishnu garden':'sector 105', 'bhondsi':'sector 11', 'surya vihar':'sector 21',
    'devilal colony':'sector 9', 'valley view estate':'gwal pahari', 'mehrauli  road':'sector 14', 'jyoti park':'sector 7',
    'ansal plaza':'sector 23', 'dayanand colony':'sector 6', 'sushant lok phase 2':'sector 55', 'chakkarpur':'sector 28',
    'greenwood city':'sector 45', 'subhash nagar':'sector 12', 'sohna road road':'sohna road', 'malibu town':'sector 47',
    'surat nagar 1':'sector 104', 'new colony':'sector 7', 'mianwali colony':'sector 12', 'jacobpura':'sector 12',
    'rajiv nagar':'sector 13', 'ashok vihar':'sector 3', 'dlf phase 1':'sector 26', 'nirvana country':'sector 50',
    'palam vihar':'sector 2', 'dlf phase 2':'sector 25', 'sushant lok phase 1':'sector 43', 'laxman vihar':'sector 4',
    'dlf phase 4':'sector 28', 'dlf phase 3':'sector 24', 'sushant lok phase 3':'sector 57', 'dlf phase 5':'sector 43',
    'rajendra park':'sector 105', 'uppals southend':'sector 49', 'sohna':'sohna road', 'ashok vihar phase 3 extension':'sector 5',
    'south city 1':'sector 41', 'ashok vihar phase 2':'sector 5',
}

# %%
df.sector.replace(replacement, inplace=True)

# %%
a = df.sector.value_counts()[df.sector.value_counts() >=3]
df = df[df['sector'].isin(a.index)]

# %%
df['sector'].value_counts()
# Out:
# sohna road                     175
# sector 102                     113
# sector 85                      110
# sector 92                      104
# sector 69                       94
# sector 65                       90
# sector 90                       90
# sector 81                       90
# sector 109                      88
# sector 79                       80
# sector 104                      73
# sector 83                       69
# sector 37d                      68
# sector 86                       67
# sector 50                       65
# sector 107                      60
# sector 108                      59
# sector 95                       57
# sector 56                       57
# sector 48                       56
# sector 89                       56
# sector 2                        55
# sector 70a                      54
# sector 70                       53
# sector 43                       53
# sector 37c                      53
# sector-33 sohna                 51
# ...

# %%
replace= {
    'sector 95a':'sector 95', 'sector 23a':'sector 23', 'sector 12a':'sector 12', 'sector 3a':'sector 3', 'sector 110 a':'sector 110',
    'patel nagar':'sector 15','a block sector 43':'sector 43','maruti kunj':'sector 12','b block sector 43':'sector 43',
    'sector-33 sohna road':'sector 33', 'sector 1 manesar':'manesar', 'sector 4 phase 2':'sector 4', 'sector 1a manesar':'manesar',
    'c block sector 43':'sector 43', 'sector 89 a':'sector 89', 'sector 2 extension':'sector 2', 'sector 36 sohna road':'sector 36'
}

# %%
df.sector.replace(replace, inplace=True)

# %%
df[df.sector == "new"]
# Out:
#                   property_name property_type                       society  \
# 1147  4 BHK Flat in New Gurgaon          flat                        dlf 76
# 1475  4 BHK Flat in New Gurgaon          flat                    sare homes
# 1648  2 BHK Flat in New Gurgaon          flat                   green court
# 3766  2 BHK Flat in New Gurgaon          flat  takshila heights sector 37 c
#
#      sector  price  price_per_sqft    area  \
# 1147    new   4.00         11428.0  3500.0
# 1475    new   0.85          4786.0  1776.0
# 1648    new   0.38          5507.0   690.0
# 3766    new   0.67          5583.0  1200.0
#
#                                 areaWithType  bedRoom  bathroom balcony  \
# 1147        Carpet area: 3500 (325.16 sq.m.)        4         4       2
# 1475     Super Built up area 1776(165 sq.m.)        4         4       3
# 1648           Carpet area: 690 (64.1 sq.m.)        2         2       1
# 3766  Super Built up area 1200(111.48 sq.m.)        2         2       2
#
# ...

# %%
df.loc[1147,'sector'] = 'sector 76'
df.loc[1475,'sector'] = 'sector 92'
df.loc[3766,'sector'] = 'sector 37'
df.loc[1648,'sector'] = 'sector 90'

# %%
df[df.sector == "new"]
# Out:
# Empty DataFrame
# Columns: [property_name, property_type, society, sector, price, price_per_sqft, area, areaWithType, bedRoom, bathroom, balcony, additionalRoom, address, floor_num, facing, agePossession, nearbyLocations, description, furnishDetails, features, rating]
# Index: []

# %%
df[df['sector'] == 'new sector 2']
# Out:
# Empty DataFrame
# Columns: [property_name, property_type, society, sector, price, price_per_sqft, area, areaWithType, bedRoom, bathroom, balcony, additionalRoom, address, floor_num, facing, agePossession, nearbyLocations, description, furnishDetails, features, rating]
# Index: []

# %%
df.shape
# Out:
# (3803, 21)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#                                     property_name property_type  \
# 0        12 Bedroom House for sale in Malibu Town         house
# 1  5 Bedroom House for sale in Sector 109 Gurgaon         house
# 2                2 BHK Flat in Sector 102 Gurgaon          flat
# 3                2 BHK Flat in Sector 99A Gurgaon          flat
# 4                             2 BHK Flat in Sohna          flat
#
#                                 society      sector  price  price_per_sqft  \
# 0                          malibu towne   sector 47   8.50         53125.0
# 1   international city by sobha phase 1  sector 109  12.00         20000.0
# 2  shapoorji pallonji joyville gurugram  sector 102   1.28         10534.0
# 3                     conscient habitat  sector 99a   0.27          5599.0
# 4                     gls arawali homes  sohna road   0.32          6722.0
#
#      area                                       areaWithType  bedRoom  \
# ...

# %%
df.drop(columns=['property_name', 'address', 'description', 'rating'],inplace=True)

# %%
df.sample(5)
# Out:
#      property_type                              society      sector  price  \
# 196           flat                 housing board colony   sector 51   0.30
# 129           flat                       dlf the ultima   sector 81   2.30
# 2614         house  international city by sobha phase 2  sector 109   9.50
# 3888          flat                      raheja vedaanta  sector 108   1.25
# 2432          flat          bestech park view sanskruti   sector 92   2.00
#
#       price_per_sqft    area  \
# 196          41666.0    72.0
# 129          14603.0  1575.0
# 2614         26389.0  3600.0
# 3888          5681.0  2200.0
# 2432          8333.0  2400.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 196                        Carpet area: 72 (6.69 sq.m.)        1         1
# 129   Super Built up area 2100(195.1 sq.m.)Carpet ar...        3         4
# 2614                        Plot area 400(334.45 sq.m.)        7         6
# ...

# %%
df.duplicated().sum()
# Out:
# 122

# %%
df.to_csv('datasets/Gurgaon/Flats/properties_cleaned_v1.csv',index=False)
